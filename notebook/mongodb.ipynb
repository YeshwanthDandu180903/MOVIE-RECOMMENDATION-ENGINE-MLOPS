# %%
import pandas as pd
import pymongo

df=pd.read_csv('C:/Users/abhis/yeshwanth/MOVIE-RECOMMENDATION-ENGINE-MLOPS/data/movies_with_images_1.csv')
df.head()
# Out:
#         id                         title  \
# 0  1223601         Sisu: Road to Revenge
# 1  1013446  Reflection in a Dead Diamond
# 2  1336189                  Delivery Run
# 3  1196067                  Worldbreaker
# 4  1439112        Muzzle: City of Wolves
#
#                                             overview  \
# 0  Returning to the house where his family was br...
# 1  When the mysterious woman in the room next doo...
# 2  A food delivery driver gets caught in a deadly...
# 3  Five years ago, a tear in the fabric of realit...
# 4  LAPD officer Jake Rosser endeavors to lead a p...
#
#                               genres  \
# 0                  ['Action', 'War']
# 1  ['Action', 'Thriller', 'Mystery']
# 2             ['Action', 'Thriller']
# 3      ['Science Fiction', 'Action']
# 4  ['Action', 'Thriller', 'Mystery']
#
#                                                 cast           director  \
# 0  ['Jorma Tommila', 'Stephen Lang', 'Richard Bra...   Jalmari Helander
# 1  ['Fabio Testi', 'Yannick Renier', 'Koen De Bou...      Hélène Cattet
# 2  ['Alexander Arnold', 'Liam James Collins', 'Jo...      Joey Palmroos
# 3  ['Milla Jovovich', 'Luke Evans', 'Meadow Willi...      Brad Anderson
# 4  ['Aaron Eckhart', 'Tanya van Graan', 'Karl Tha...  John Stalberg Jr.
#
#                                             keywords  rating  vote_count  \
# 0          ['sequel', 'karelia', 'absurd', 'amused']   7.521         282
# 1                                                 []   5.900          48
# 2  ['winter', 'minnesota', 'wilderness', 'slacker...   5.500          20
# 3    ['monster', 'climate change', 'global warming']   6.129          32
# 4                             ['police dog', 'lapd']   6.814          43
#
#   release_date  imdb_rating imdb_votes  \
# 0   2025-10-21          NaN        NaN
# 1   2025-06-25          NaN        NaN
# 2   2025-09-10          NaN        NaN
# 3   2025-10-30          NaN        NaN
# 4   2025-11-13          NaN        NaN
#
#                                           poster_url  \
# 0  https://image.tmdb.org/t/p/w500/jNsttCWZyPtW66...
# 1  https://image.tmdb.org/t/p/w500/5CdRxBu7jRDHjt...
# 2  https://image.tmdb.org/t/p/w500/eCA5maHDlZtXNT...
# 3  https://image.tmdb.org/t/p/w500/7K8w6mdrJp0oaS...
# 4  https://image.tmdb.org/t/p/w500/8qTMRmC07XCGid...
#
#                                         backdrop_url
# 0  https://image.tmdb.org/t/p/w500/yCatt8lmp3oRFE...
# 1  https://image.tmdb.org/t/p/w500/AePlQ3osZShJmb...
# 2  https://image.tmdb.org/t/p/w500/hvut2slhhgJ31U...
# 3  https://image.tmdb.org/t/p/w500/4mZ06VpfpAPuaU...
# 4  https://image.tmdb.org/t/p/w500/ncI1PlBcANixIk...

# %%
#df should be converted into dictionary before pushing into mongodb
data=df.to_dict(orient='records')
data
# Out:
# [{'id': 1223601,
#   'title': 'Sisu: Road to Revenge',
#   'overview': 'Returning to the house where his family was brutally murdered during the war, ‘the man who refuses to die’ dismantles it, loads it on a truck, and is determined to rebuild it somewhere safe in their honor. When the commander who killed his family comes back hellbent on finishing the job, a relentless, eye-popping cross-country chase ensues.',
#   'genres': "['Action', 'War']",
#   'cast': "['Jorma Tommila', 'Stephen Lang', 'Richard Brake', 'Tommi Korpela', 'Kaspar Velberg', 'Pääru Oja', 'Erki Laur', 'Maksim Demidov', 'Mart Nurk', 'Riho Rosberg']",
#   'director': 'Jalmari Helander',
#   'keywords': "['sequel', 'karelia', 'absurd', 'amused']",
#   'rating': 7.521,
#   'vote_count': 282,
#   'release_date': '2025-10-21',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/jNsttCWZyPtW66MjhUozBzVsRb7.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/yCatt8lmp3oRFEcOZF8KHhsiASQ.jpg'},
#  {'id': 1013446,
#   'title': 'Reflection in a Dead Diamond',
#   'overview': "When the mysterious woman in the room next door disappears, a debonair 70-year-old ex-spy living in a luxury hotel on the Côte d'Azur is confronted by the demons and darlings of a lurid past in which moviemaking, memories and madness collide.",
#   'genres': "['Action', 'Thriller', 'Mystery']",
#   'cast': "['Fabio Testi', 'Yannick Renier', 'Koen De Bouw', 'Maria de Medeiros', 'Thi-Mai Nguyen', 'Céline Camara', 'Kézia Quental', 'Manon Beuchot', 'Hervé Sogne', 'Sylvia Camarda']",
#   'director': 'Hélène Cattet',
#   'keywords': '[]',
#   'rating': 5.9,
#   'vote_count': 48,
#   'release_date': '2025-06-25',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/5CdRxBu7jRDHjthkAL8vE0GdKUD.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/AePlQ3osZShJmbNj8tzQ3NoMTQF.jpg'},
#  {'id': 1336189,
#   'title': 'Delivery Run',
#   'overview': 'A food delivery driver gets caught in a deadly chase in the icy Minnesota wilderness, pursued by a crazed snowplow driver for unknown reasons, facing life-threatening situations and forced to outsmart his relentless pursuer alone.',
#   'genres': "['Action', 'Thriller']",
#   'cast': "['Alexander Arnold', 'Liam James Collins', 'Joe Gallina', 'Nadine Higgin', 'Jussi Lampi', 'Joey Palmroos', 'Darren McStay', 'Thom Chacon', 'Jeremiah Crosby', 'Celin El Azizi']",
#   'director': 'Joey Palmroos',
#   'keywords': "['winter', 'minnesota', 'wilderness', 'slacker', 'salesman', 'snow', 'pursuit', 'goldfish', 'driver', 'road rage', 'traveling salesman', 'american wilderness', 'woodlands', 'snow plow', 'winter storm', 'ice', 'vehicle', 'car', 'delivery driver']",
#   'rating': 5.5,
#   'vote_count': 20,
#   'release_date': '2025-09-10',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/eCA5maHDlZtXNTtiLXenwnEw7tc.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/hvut2slhhgJ31UNa9Df7jFfAS0x.jpg'},
#  {'id': 1196067,
#   'title': 'Worldbreaker',
#   'overview': 'Five years ago, a tear in the fabric of reality brought creatures to our world from an alternate dimension bent on our destruction. A father hides his daughter on an island to keep her safe while he prepares her for survival and the battles to come. But when the world is about to break, no place is safe.',
#   'genres': "['Science Fiction', 'Action']",
#   'cast': "['Milla Jovovich', 'Luke Evans', 'Meadow Williams', 'Mila Harris', 'Billie Boulet', 'Kevin Glynn', 'Chris Finlayson', 'Charis Agbonlahor', 'Laura Dee', 'Steven Calvert']",
#   'director': 'Brad Anderson',
#   'keywords': "['monster', 'climate change', 'global warming']",
#   'rating': 6.129,
#   'vote_count': 32,
#   'release_date': '2025-10-30',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/7K8w6mdrJp0oaSoKWGyjSZ4Zv2z.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/4mZ06VpfpAPuaUPn1SEV0brbbxe.jpg'},
#  {'id': 1439112,
#   'title': 'Muzzle: City of Wolves',
#   'overview': 'LAPD officer Jake Rosser endeavors to lead a peaceful life with his family and retired K-9 officer, Socks. However, tranquility dissolves into chaos when a gang targets them in a brutal attack. Alongside his new K-9 partner Argos, Jake launches into a relentless pursuit of justice, determined to protect his loved ones.',
#   'genres': "['Action', 'Thriller', 'Mystery']",
#   'cast': "['Aaron Eckhart', 'Tanya van Graan', 'Karl Thaning', 'Nicole Fortuin', 'Adrian Collins', 'Hakeem Kae-Kazim', 'Bongo Mbutuma', 'Grant Ross', 'Jessica Stanley', 'Lindy Abromowitz']",
#   'director': 'John Stalberg Jr.',
#   'keywords': "['police dog', 'lapd']",
#   'rating': 6.814,
#   'vote_count': 43,
#   'release_date': '2025-11-13',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/8qTMRmC07XCGidnKQFLbRM3FoDU.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/ncI1PlBcANixIkgQSnjsSRz4OyT.jpg'},
#  {'id': 1491902,
#   'title': 'Bang',
#   'overview': 'Follows a ruthless hitman who, after narrowly escaping a fatal attempt on his life, betrays his gang in an effort to find forgiveness but ends up becoming a target himself.',
#   'genres': "['Action', 'Thriller']",
#   'cast': "['Jack Kesy', 'Peter Weller', 'Tristin Mays', 'Kane Kosugi', 'Steve Bastoni', 'Tofan Pirani', 'Bear Williams', 'Elliott Allison', 'Carlo Natale', 'Toma Morozova']",
#   'director': 'Wych Kaosayananda',
#   'keywords': "['hitman']",
#   'rating': 6.306,
#   'vote_count': 18,
#   'release_date': '2025-07-11',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/8SUzKOqe2ectvhYdSnR7Vq2F3n1.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/x3s2lEGNguUnQ5YH3Goq7Ud7Lcn.jpg'},
#  {'id': 798645,
#   'title': 'The Running Man',
#   'overview': "Desperate to save his sick daughter, working-class Ben Richards is convinced by The Running Man's charming but ruthless producer to enter the deadly competition game as a last resort. But Ben's defiance, instincts, and grit turn him into an unexpected fan favorite — and a threat to the entire system. As ratings skyrocket, so does the danger, and Ben must outwit not just the Hunters, but a nation addicted to watching him fall.",
#   'genres': "['Action', 'Thriller', 'Science Fiction']",
#   'cast': '[\'Glen Powell\', \'Josh Brolin\', \'Colman Domingo\', \'Lee Pace\', \'Michael Cera\', \'Emilia Jones\', \'William H. Macy\', \'Daniel Ezra\', \'Jayme Lawson\', "Katy O\'Brian"]',
#   'director': 'Edgar Wright',
#   'keywords': "['based on novel or book', 'dark comedy', 'survival', 'on the run', 'television network', 'near future', 'malicious', 'depressing', 'mean spirited', 'dystopian future', 'dystopian sci-fi']",
#   'rating': 6.826,
#   'vote_count': 743,
#   'release_date': '2025-11-11',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/dKL78O9zxczVgjtNcQ9UkbYLzqX.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/aHj7d7wSLqrg5cjAcgHhiGr97Ih.jpg'},
#  {'id': 1589891,
#   'title': 'A Time for Bravery',
#   'overview': 'A psychoanalyst on community service aids an agent shattered by infidelity; together, they will confront danger and discover second chances.',
#   'genres': "['Comedy', 'Action']",
#   'cast': "['Luis Gerardo Méndez', 'Memo Villegas', 'Christian Tappán', 'Verónica Bravo', 'Noé Hernández', 'Fernando Cuautle', 'Santiago Sandoval']",
#   'director': 'Ariel Winograd',
#   'keywords': '[]',
#   'rating': 7.931,
#   'vote_count': 36,
#   'release_date': '2025-12-18',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/qKKG22O5pFxqglG0oMjWTjQWCNl.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/gtuXARxjGdfsGFqEwggBB8zUJza.jpg'},
#  {'id': 1419406,
#   'title': "The Shadow's Edge",
#   'overview': 'Macau Police brings the tracking expert police officer out of retirement to help catch a dangerous group of professional thieves.',
#   'genres': "['Action', 'Crime', 'Thriller']",
#   'cast': "['Jackie Chan', 'Zhang Zifeng', 'Tony Leung Ka-fai', 'Ci Sha', 'Jun', 'Zhou Zhengjie', 'Wang Ziyi', 'Lang Yueting', 'Li Zhekun', 'Zac Wang']",
#   'director': 'Larry Yang',
#   'keywords': '[]',
#   'rating': 6.611,
#   'vote_count': 175,
#   'release_date': '2025-08-16',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/e0RU6KpdnrqFxDKlI3NOqN8nHL6.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/4BtL2vvEufDXDP4u6xQjjQ1Y2aT.jpg'},
#  {'id': 76600,
#   'title': 'Avatar: The Way of Water',
#   'overview': 'Set more than a decade after the events of the first film, learn the story of the Sully family (Jake, Neytiri, and their kids), the trouble that follows them, the lengths they go to keep each other safe, the battles they fight to stay alive, and the tragedies they endure.',
#   'genres': "['Action', 'Adventure', 'Science Fiction']",
#   'cast': "['Sam Worthington', 'Zoe Saldaña', 'Sigourney Weaver', 'Stephen Lang', 'Kate Winslet', 'Cliff Curtis', 'Joel David Moore', 'CCH Pounder', 'Edie Falco', 'Jemaine Clement']",
#   'director': 'James Cameron',
#   'keywords': "['dying and death', 'loss of loved one', 'alien life-form', 'resurrection', 'dysfunctional family', 'sequel', 'alien planet', 'distant future', 'adopted child', 'rebirth', 'family dynamics', 'adopted son', 'stronger villain', 'war', 'stereoscopic film', 'sentimental', 'awestruck', 'hopeful', 'modest']",
#   'rating': 7.608,
#   'vote_count': 13273,
#   'release_date': '2022-12-14',
#   'imdb_rating': 7.5,
#   'imdb_votes': '551,293',
#   'poster_url': 'https://image.tmdb.org/t/p/w500/t6HIqrRAclMCA60NsSmeqe9RmNV.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/cd8YDn7M0lfaHhZdU6MvCDxPalP.jpg'},
#  {'id': 533533,
#   'title': 'TRON: Ares',
#   'overview': "A highly sophisticated Program called Ares is sent from the digital world into the real world on a dangerous mission, marking humankind's first encounter with A.I. beings.",
#   'genres': "['Science Fiction', 'Adventure', 'Action']",
#   'cast': "['Jared Leto', 'Greta Lee', 'Evan Peters', 'Gillian Anderson', 'Jodie Turner-Smith', 'Jeff Bridges', 'Hasan Minhaj', 'Arturo Castro', 'Cameron Monaghan', 'Sarah Desjardins']",
#   'director': 'Joachim Rønning',
#   'keywords': "['artificial intelligence (a.i.)', 'computer program', 'simulation', 'computer simulation', 'sequel', 'business rivalry', 'real world', 'digital world']",
#   'rating': 6.585,
#   'vote_count': 817,
#   'release_date': '2025-10-08',
#   'imdb_rating': 6.5,
#   'imdb_votes': '37,738',
#   'poster_url': 'https://image.tmdb.org/t/p/w500/chpWmskl3aKm1aTZqUHRCtviwPy.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/min9ZUDZbiguTiQ7yz1Hbqk78HT.jpg'},
#  {'id': 19995,
#   'title': 'Avatar',
#   'overview': 'In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.',
#   'genres': "['Action', 'Adventure', 'Fantasy', 'Science Fiction']",
#   'cast': "['Sam Worthington', 'Zoe Saldaña', 'Sigourney Weaver', 'Stephen Lang', 'Michelle Rodriguez', 'Giovanni Ribisi', 'Joel David Moore', 'CCH Pounder', 'Wes Studi', 'Laz Alonso']",
#   'director': 'James Cameron',
#   'keywords': "['paraplegic', 'attachment to nature', 'culture clash', 'indigenous', 'space travel', 'space colony', 'tribe', 'alien planet', 'distant future', 'marine', 'battle', 'love affair', 'scientist', 'nature', 'native peoples', 'power relations', 'tribal customs', 'tribal people', 'tribal chief', 'cryonics', 'spiritual community', '22nd century', 'save the planet', 'racial discrimination', 'soldiers', 'stereoscopic film', 'awestruck', 'bold', 'exhilarated']",
#   'rating': 7.597,
#   'vote_count': 33024,
#   'release_date': '2009-12-16',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/gKY6q7SjCkAU6FqvqWybDYgUKIF.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/7JNzw1tSZZEgsBw6lu0VfO2X2Ef.jpg'},
#  {'id': 1242898,
#   'title': 'Predator: Badlands',
#   'overview': 'Cast out from his clan, a young Predator finds an unlikely ally in a damaged android and embarks on a treacherous journey in search of the ultimate adversary.',
#   'genres': "['Action', 'Science Fiction', 'Adventure']",
#   'cast': "['Elle Fanning', 'Dimitrius Schuster-Koloamatangi', 'Ravi Narayan', 'Michael Homick', 'Stefan Grube', 'Reuben De Jong', 'Cameron Brown', 'Alison Wright', 'Matt Duffer', 'Ross Duffer']",
#   'director': 'Dan Trachtenberg',
#   'keywords': "['survival', 'outcast', 'alien planet', 'thoughtful', 'team up', 'negative', 'arrogant', 'condescending', 'farcical', 'ridiculous']",
#   'rating': 7.333,
#   'vote_count': 683,
#   'release_date': '2025-11-05',
#   'imdb_rating': 7.6,
#   'imdb_votes': '18,100',
#   'poster_url': 'https://image.tmdb.org/t/p/w500/ef2QSeBkrYhAdfsWGXmp0lvH0T1.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/ebyxeBh56QNXxSJgTnmz7fXAlwk.jpg'},
#  {'id': 1387382,
#   'title': 'Hunting Season',
#   'overview': 'When a reclusive survivalist and his daughter rescue a mysterious, wounded woman from a river, they become entangled in a deadly web of violence and revenge, forcing them to confront a brutal criminal to survive.',
#   'genres': "['Action', 'Drama', 'Thriller']",
#   'cast': "['Mel Gibson', 'Shelley Hennig', 'Jordi Mollà', 'Sofia Hublitz', 'A.J. Buckley', 'James DuMont', 'Rocky Myers', 'Oliver Trevena', 'Scarlet Rose Stallone', 'Rob Moran']",
#   'director': 'Raja Collins',
#   'keywords': '[]',
#   'rating': 7.082,
#   'vote_count': 67,
#   'release_date': '2025-12-05',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/cbryTyaWdqrKpQCw6K7zm2jrB5v.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/eJ0HooOOD1uzI39CfOQNWIiWKlJ.jpg'},
#  {'id': 1218925,
#   'title': 'Chainsaw Man - The Movie: Reze Arc',
#   'overview': "In a brutal war between devils, hunters, and secret enemies, a mysterious girl named Reze has stepped into Denji's world, and he faces his deadliest battle yet, fueled by love in a world where survival knows no rules.",
#   'genres': "['Animation', 'Action', 'Romance', 'Fantasy']",
#   'cast': "['Kikunosuke Toya', 'Reina Ueda', 'Tomori Kusunoki', 'Shogo Sakata', 'Maaya Uchida', 'Natsuki Hanae', 'Karin Takahashi', 'Fairouz Ai', 'Yuuya Uchida', 'Shiori Izawa']",
#   'director': 'Tatsuya Yoshihara',
#   'keywords': "['regret', 'fight', 'identity', 'supernatural', 'manipulation', 'secret organization', 'gore', 'sequel', 'loneliness', 'chainsaw', 'based on manga', 'demon', 'adult animation', 'tragic romance', 'shounen', 'anime']",
#   'rating': 8.308,
#   'vote_count': 485,
#   'release_date': '2025-09-19',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/pHyxb2RV5wLlboAwm9ZJ9qTVEDw.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/kfXgo2rMF1A19celCwLyQ4Xwpf8.jpg'},
#  {'id': 1311031,
#   'title': 'Demon Slayer: Kimetsu no Yaiba Infinity Castle',
#   'overview': 'The Demon Slayer Corps are drawn into the Infinity Castle, where Tanjiro, Nezuko, and the Hashira face terrifying Upper Rank demons in a desperate fight as the final battle against Muzan Kibutsuji begins.',
#   'genres': "['Animation', 'Action', 'Fantasy']",
#   'cast': "['Natsuki Hanae', 'Takahiro Sakurai', 'Akira Ishida', 'Hiro Shimono', 'Yoshimasa Hosoya', 'Saori Hayami', 'Mamoru Miyano', 'Reina Ueda', 'Yuichi Nakamura', 'Lynn']",
#   'director': 'Haruo Sotozaki',
#   'keywords': "['supernatural', 'affectation', 'sequel', 'based on manga', 'demon', 'shounen', 'anime', 'brother sister relationship', 'taisho period', 'admiring']",
#   'rating': 7.634,
#   'vote_count': 611,
#   'release_date': '2025-07-18',
#   'imdb_rating': 8.5,
#   'imdb_votes': '51,555',
#   'poster_url': 'https://image.tmdb.org/t/p/w500/fWVSwgjpT2D78VUh6X8UBd2rorW.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/1RgPyOhN4DRs225BGTlHJqCudII.jpg'},
#  {'id': 1247002,
#   'title': 'The Old Woman with the Knife',
#   'overview': "Aging assassin Hornclaw has seen it all, but she never expected to mentor a reckless rookie like Bullfight. As their unlikely bond deepens, cracks form in the underworld they navigate together. When Hornclaw discovers someone wants her dead, she's thrust into a deadly game of deception. With enemies closing in and trust in short supply, survival means staying sharp—both blade and mind.",
#   'genres': "['Action', 'Mystery', 'Drama']",
#   'cast': "['Lee Hye-young', 'Kim Sung-cheol', 'Yeon Woo-jin', 'Kim Moo-yul', 'Shin Sia', 'Kim Kang-woo', 'Choi Moo-seong', 'Ok Ja-yeon', 'Lee Hyun-gul', 'Lee Yong-nyeo']",
#   'director': 'Min Kyu-dong',
#   'keywords': "['based on novel or book']",
#   'rating': 6.588,
#   'vote_count': 40,
#   'release_date': '2025-04-30',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/wbmxnsv41vsg5UEaNDlf203dOWw.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/fepnF3W4VP3s8ui8nDtrlsFVYwO.jpg'},
#  {'id': 1180831,
#   'title': 'Troll 2',
#   'overview': 'When a dangerous new troll unleashes devastation across their homeland, Nora, Andreas and Major Kris embark on their most perilous mission yet.',
#   'genres': "['Action', 'Fantasy', 'Thriller']",
#   'cast': "['Ine Marie Wilmann', 'Kim S. Falck-Jørgensen', 'Mads Sjøgård Pettersen', 'Sara Khorami', 'Karoline Viktoria Sletteng Garvang', 'Anne Krigsvoll', 'Duc Mai-The', 'Jon Ketil Johnsen', 'Ola G. Furuseth', 'Yusuf Toosh Ibra']",
#   'director': 'Roar Uthaug',
#   'keywords': "['mythical creature', 'sequel', 'troll', 'kaiju', 'oslo, norway', 'monster movie', 'norwegian folklore', 'action thriller', 'indifferent']",
#   'rating': 6.628,
#   'vote_count': 304,
#   'release_date': '2025-11-30',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/p6xAExLNFbHcLfvSuvLPoM8aqZU.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/lZYMXx74pWmbj5Q5jp1QaMvmuuR.jpg'},
#  {'id': 7451,
#   'title': 'xXx',
#   'overview': 'Xander Cage is your standard adrenaline junkie with no fear and a lousy attitude. When the US Government "recruits" him to go on a mission, he\'s not exactly thrilled. His mission: to gather information on an organization that may just be planning the destruction of the world, led by the nihilistic Yorgi.',
#   'genres': "['Action', 'Adventure', 'Thriller', 'Crime', 'Drama']",
#   'cast': "['Vin Diesel', 'Asia Argento', 'Marton Csokas', 'Samuel L. Jackson', 'Michael Roof', 'Richy Müller', 'Werner Daehn', 'Petr Jákl', 'Jan Filipenský', 'Tom Everett']",
#   'director': 'Rob Cohen',
#   'keywords': "['mission', 'biological weapon', 'sports car', 'cold war', 'prague, czech republic', 'nsa agent', 'adrenaline junkie', 'thrill seeker', 'joyful']",
#   'rating': 6.0,
#   'vote_count': 4700,
#   'release_date': '2002-08-09',
#   'imdb_rating': 5.9,
#   'imdb_votes': '192,071',
#   'poster_url': 'https://image.tmdb.org/t/p/w500/xeEw3eLeSFmJgXZzmF2Efww0q3s.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/2OHa6ukEq3Hce7Pc2kvu8wkmMFY.jpg'},
#  {'id': 1054867,
#   'title': 'One Battle After Another',
#   'overview': 'Washed-up revolutionary Bob exists in a state of stoned paranoia, surviving off-grid with his spirited, self-reliant daughter, Willa. When his evil nemesis resurfaces after 16 years and she goes missing, the former radical scrambles to find her, father and daughter both battling the consequences of his past.',
#   'genres': "['Thriller', 'Crime', 'Action']",
#   'cast': "['Leonardo DiCaprio', 'Sean Penn', 'Chase Infiniti', 'Benicio del Toro', 'Regina Hall', 'Teyana Taylor', 'Wood Harris', 'Tony Goldwyn', 'D.W. Moffett', 'Paul Grimstad']",
#   'director': 'Paul Thomas Anderson',
#   'keywords': "['rebellion', 'based on novel or book', 'resistance', 'usa–mexico border', 'riot', 'interracial relationship', 'on the run', 'xenophobia', 'aftercreditsstinger', 'missing daughter', 'white supremacy', 'anti-fascism', 'father daughter relationship', 'revolutionaries', 'african american', 'anti-racism', 'immigration detention center']",
#   'rating': 7.479,
#   'vote_count': 2022,
#   'release_date': '2025-09-23',
#   'imdb_rating': 7.9,
#   'imdb_votes': '218,376',
#   'poster_url': 'https://image.tmdb.org/t/p/w500/r4uXvqCeco0KmO0CjlhXuTEFuSE.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/zpEWFNqoN8Qg1SzMMHmaGyOBTdW.jpg'},
#  {'id': 1083637,
#   'title': 'Kantara - A Legend: Chapter 1',
#   'overview': 'During the Kadamba reign, King Vijayendra, the ruler of the fictional feudatory land of Bangra, meets his final fate while venturing into the mystical forest of Kantara. Witnessing this, his son Rajashekara seals the borders of their realm. Later, Prince Kulashekara reopens them through a brutal massacre. The protagonist, Berme, in search of prosperity, crosses the divide and ignites a conflict of faith, power, and destiny between the Kingdom and Nature.',
#   'genres': "['Action', 'Drama', 'Fantasy']",
#   'cast': "['Rishab Shetty', 'Rukmini Vasanth', 'Jayaram', 'Gulshan Devaiah', 'Ramitha Shailendra', 'Pramod Shetty', 'Naveen D. Padil', 'Rakesh Poojari', 'Prakash Thuminad', 'Deepak Rai Panaje']",
#   'director': 'Rishab Shetty',
#   'keywords': '[]',
#   'rating': 7.0,
#   'vote_count': 53,
#   'release_date': '2025-10-01',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/ehQPboTPaIMkMUOoNOh8e7pZ5Rp.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/w57nxiBIODAYHLRs1xmrCY9zEFe.jpg'},
#  {'id': 1149167,
#   'title': 'High Rollers',
#   'overview': 'A master thief must pull off a dangerous casino heist when his nemesis kidnaps his lover. Caught between rival criminals and FBI pursuit, he risks all to save her and score big.',
#   'genres': "['Action', 'Crime', 'Thriller']",
#   'cast': "['John Travolta', 'Gina Gershon', 'Lukas Haas', 'Quavo', 'Natali Yura', 'Noel Gugliemi', 'Swen Temmel', 'Demián Castro', 'Alex Hurt', 'Danny Pardo']",
#   'director': 'Randall Emmett',
#   'keywords': "['casino heist']",
#   'rating': 6.577,
#   'vote_count': 91,
#   'release_date': '2025-03-14',
#   'imdb_rating': 3.8,
#   'imdb_votes': '1,020',
#   'poster_url': 'https://image.tmdb.org/t/p/w500/hHowAaChDjwueySmwVbsjHmpWa.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/me3SisKfnxwBP69aOVKAVMw9vDM.jpg'},
#  {'id': 1291608,
#   'title': 'Dhurandhar',
#   'overview': 'After the hijacking of IC-814 in 1999 and the Parliament attack in 2001, India’s Intelligence Bureau Chief, Ajay Sanyal devised an indomitable mission to intrude and rupture the terrorist network in Pakistan, by infiltrating the underworld mafia of Karachi. A 20-year-old boy from Punjab, held captive for a revenge crime, is identified by Sanyal to execute his elaborate plan.',
#   'genres': "['Action', 'Thriller']",
#   'cast': "['Ranveer Singh', 'Akshaye Khanna', 'R. Madhavan', 'Arjun Rampal', 'Sanjay Dutt', 'Sara Arjun', 'Rakesh Bedi', 'Danish Pandor', 'Gaurav Gera', 'Naveen Kaushik']",
#   'director': 'Aditya Dhar',
#   'keywords': "['patriotism', 'nationalism', 'controversy', 'gore', 'torture', 'terrorism', 'gun violence', 'bloodshed', 'political corruption', 'sexual assault', '1990s', 'spy thriller', 'racial discrimination', '2000s', 'chase scene', 'inspired by true events']",
#   'rating': 6.3,
#   'vote_count': 112,
#   'release_date': '2025-12-05',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/8FHOtUpNIk5ZPEay2N2EY5lrxkv.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/yRYgvo2crAeHzqKwXMVtEaDx7Qq.jpg'},
#  {'id': 980477,
#   'title': 'Ne Zha 2',
#   'overview': 'After a catastrophic event leaves their bodies destroyed, Ne Zha and Ao Bing are granted a fragile second chance at life. As tensions rise between the dragon clans and celestial forces, the two must undergo a series of perilous trials that will test their bond, challenge their identities, and decide the fate of both mortals and immortals.',
#   'genres': "['Animation', 'Fantasy', 'Adventure', 'Action']",
#   'cast': "['Lu Yanting', 'Joseph', 'Han Mo', 'Chen Hao', 'Lu Qi', 'Zhang Jiaming', 'Yang Wei', 'Wang Deshun', 'Yu Chen', 'Li Nan']",
#   'director': 'Jiao Zi',
#   'keywords': "['fight', 'magic', 'based on myths, legends or folklore', '3d animation', 'nezha', 'chinese mythology', 'donghua']",
#   'rating': 8.09,
#   'vote_count': 519,
#   'release_date': '2025-01-29',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/cb5NyNrqiCNNoDkA8FfxHAtypdG.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/8btfz81bOJ2lC7cujYBTw03wzg3.jpg'},
#  {'id': 1033462,
#   'title': 'Bureau 749',
#   'overview': 'A traumatized young man with physical abnormalities is forced to join a mysterious bureau to confront a disaster spreading across the earth caused by an unknown creature. He embarks on an adventure uncovering mysteries about his life.',
#   'genres': "['Action', 'Adventure', 'Science Fiction']",
#   'cast': "['Karry Wang', 'Miao Miao', 'Ryan Zheng', 'Ren Min', 'Xin Baiqing', 'Jerry Lee', 'Ning Chang', 'Yang Haoyu', 'Yu Kailei', 'Li Meng']",
#   'director': 'Lu Chuan',
#   'keywords': "['joyful', 'mezcla documental y ficción']",
#   'rating': 6.292,
#   'vote_count': 65,
#   'release_date': '2024-10-01',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/flykCMw22y6yv8vKnBjmsW3pneo.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/lf8IZ86ajGpgbuyHCZrXUeAMmvy.jpg'},
#  {'id': 1539104,
#   'title': 'JUJUTSU KAISEN: Execution -Shibuya Incident x The Culling Game Begins-',
#   'overview': "A veil abruptly descends over the busy Shibuya area amid the bustling Halloween crowds, trapping countless civilians inside. Satoru Gojo, the strongest jujutsu sorcerer, steps into the chaos. But lying in wait are curse users and spirits scheming to seal him away. Yuji Itadori, accompanied by his classmates and other top-tier jujutsu sorcerers, enters the fray in an unprecedented clash of curses — the Shibuya Incident. In the aftermath, ten colonies across Japan are transformed into dens of curses in a plan orchestrated by Noritoshi Kamo. As the deadly Culling Game starts, Special Grade sorcerer Yuta Okkotsu is assigned to carry out Yuji's execution for his perceived crimes. A compilation movie of Shibuya Incident including the first two episodes of the Culling Games arc.",
#   'genres': "['Animation', 'Action']",
#   'cast': "['Junya Enoki', 'Megumi Ogata', 'Koji Yusa', 'Daisuke Namikawa', 'Yuma Uchida', 'Asami Seto', 'Kenjiro Tsuda', 'Subaru Kimura', 'Yuichi Nakamura', 'Takahiro Sakurai']",
#   'director': 'Shota Goshozono',
#   'keywords': "['compilation', 'based on manga', 'edited from tv series', 'shounen', 'anime']",
#   'rating': 5.29,
#   'vote_count': 69,
#   'release_date': '2025-11-07',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/v0s3dx6am0RzfsuK3KdEy8ZoCDs.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/gtKglOSEq3d4MgQE4VsrT1sRkd0.jpg'},
#  {'id': 1217602,
#   'title': 'London Calling',
#   'overview': 'After fleeing the UK from a job gone wrong, a down on his luck hitman is forced to babysit the son of his new crime boss and show him how to become a man.',
#   'genres': "['Action', 'Crime', 'Comedy', 'Thriller']",
#   'cast': "['Josh Duhamel', 'Aidan Gillen', 'Jeremy Ray Taylor', 'Rick Hoffman', 'Arnold Vosloo', 'Finnley Barrett', 'Daniel Lasker', 'Daniah De Villiers', 'Nathan Castle', 'Neil Sandilands']",
#   'director': 'Allan Ungar',
#   'keywords': "['south africa', 'teenage boy', 'contract killer', 'action comedy', 'comedy thriller']",
#   'rating': 6.983,
#   'vote_count': 59,
#   'release_date': '2025-09-18',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/cpQ4VxBJO7vGV3IUdKzSNf4tH9V.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/1dqFuNiutgBdNF9d5QOQBWHHvft.jpg'},
#  {'id': 575265,
#   'title': 'Mission: Impossible - The Final Reckoning',
#   'overview': "Ethan Hunt and team continue their search for the terrifying AI known as the Entity — which has infiltrated intelligence networks all over the globe — with the world's governments and a mysterious ghost from Hunt's past on their trail. Joined by new allies and armed with the means to shut the Entity down for good, Hunt is in a race against time to prevent the world as we know it from changing forever.",
#   'genres': "['Action', 'Thriller', 'Adventure']",
#   'cast': "['Tom Cruise', 'Hayley Atwell', 'Ving Rhames', 'Simon Pegg', 'Esai Morales', 'Pom Klementieff', 'Henry Czerny', 'Holt McCallany', 'Janet McTeer', 'Nick Offerman']",
#   'director': 'Christopher McQuarrie',
#   'keywords': "['mask', 'artificial intelligence (a.i.)', 'diving', 'submarine', 'espionage', 'spy', 'nuclear missile', 'fake identity', 'secret agent', 'stunt', 'sequel', 'secret government organization', 'infiltration', 'terrorist plot', 'fictional government agency', 'misinformation', 'government agency', 'based on tv series', 'suspenseful']",
#   'rating': 7.243,
#   'vote_count': 2244,
#   'release_date': '2025-05-17',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/z53D72EAOxGRqdr7KXXWp9dJiDe.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/xPNDRM50a58uvv1il2GVZrtWjkZ.jpg'},
#  {'id': 1061474,
#   'title': 'Superman',
#   'overview': 'Superman, a journalist in Metropolis, embarks on a journey to reconcile his Kryptonian heritage with his human upbringing as Clark Kent.',
#   'genres': "['Science Fiction', 'Adventure', 'Action']",
#   'cast': "['David Corenswet', 'Rachel Brosnahan', 'Nicholas Hoult', 'Edi Gathegi', 'Nathan Fillion', 'Isabela Merced', 'María Gabriela de Faría', 'Skyler Gisondo', 'Alan Tudyk', 'Grace Chan']",
#   'director': 'James Gunn',
#   'keywords': "['superhero', 'based on comic', 'super power', 'aftercreditsstinger', 'duringcreditsstinger', 'supervillain', 'dc universe (dcu)', 'anti-imperialism', 'amused']",
#   'rating': 7.4,
#   'vote_count': 4036,
#   'release_date': '2025-07-09',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/ldyfo0BKmz5rWtJJKCvwaNS4cJT.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/eU7IfdWq8KQy0oNd4kKXS0QUR08.jpg'},
#  {'id': 152760,
#   'title': 'The Monuments Men',
#   'overview': 'Based on the true story of the greatest treasure hunt in history, The Monuments Men is an action drama focusing on seven over-the-hill, out-of-shape museum directors, artists, architects, curators, and art historians who went to the front lines of WWII to rescue the world’s artistic masterpieces from Nazi thieves and return them to their rightful owners.  With the art hidden behind enemy lines, how could these guys hope to succeed?',
#   'genres': "['War', 'Drama', 'History', 'Action']",
#   'cast': "['George Clooney', 'Matt Damon', 'Bill Murray', 'John Goodman', 'Cate Blanchett', 'Hugh Bonneville', 'Sam Hazeldine', 'Jean Dujardin', 'Bob Balaban', 'Holger Handtke']",
#   'director': 'George Clooney',
#   'keywords': "['nazi', 'world war ii', 'art theft', 'post world war ii']",
#   'rating': 6.064,
#   'vote_count': 3731,
#   'release_date': '2014-01-24',
#   'imdb_rating': 6.1,
#   'imdb_votes': '146,728',
#   'poster_url': 'https://image.tmdb.org/t/p/w500/wiWAg4mKV2S4vImPxsPRIdj2R2B.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/uLBJtONQwHoGc61vbIfoC6a9gUp.jpg'},
#  {'id': 1448560,
#   'title': 'Wildcat',
#   'overview': 'An ex-black ops team reunite to pull off a desperate heist in order to save the life of their leader’s eight-year-old daughter.',
#   'genres': "['Action', 'Thriller', 'Crime']",
#   'cast': "['Kate Beckinsale', 'Lewis Tan', 'Alice Krige', 'Charles Dance', 'Rasmus Hardiker', 'Mathilde Warnier', 'Bailey Patrick', 'Tom Bennett', 'Matt Willis', 'Roxy Striar']",
#   'director': 'James Nunn',
#   'keywords': "['playful', 'embarrassed']",
#   'rating': 6.356,
#   'vote_count': 52,
#   'release_date': '2025-11-19',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/h893ImjM6Fsv5DFhKJdlZFZIJno.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/pAyImoslSnpMgjRwhaS5ZEdl8UI.jpg'},
#  {'id': 617126,
#   'title': 'The Fantastic 4: First Steps',
#   'overview': "Against the vibrant backdrop of a 1960s-inspired, retro-futuristic world, Marvel's First Family is forced to balance their roles as heroes with the strength of their family bond, while defending Earth from a ravenous space god called Galactus and his enigmatic Herald, Silver Surfer.",
#   'genres': "['Science Fiction', 'Adventure', 'Action']",
#   'cast': "['Pedro Pascal', 'Vanessa Kirby', 'Ebon Moss-Bachrach', 'Joseph Quinn', 'Ralph Ineson', 'Julia Garner', 'Paul Walter Hauser', 'Natasha Lyonne', 'Sarah Niles', 'Mark Gatiss']",
#   'director': 'Matt Shakman',
#   'keywords': "['strong woman', 'superhero', 'based on comic', 'end of the world', 'family', 'super power', 'superhero team', 'alternative reality', 'aftercreditsstinger', 'duringcreditsstinger', 'marvel cinematic universe (mcu)', '1960s', 'retrofuturism', 'intense', 'awestruck', 'commanding', 'hopeful']",
#   'rating': 7.009,
#   'vote_count': 2687,
#   'release_date': '2025-07-23',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/abqOz6EL3yXyOOafCPZxjL1M5bQ.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/5CKcXxo5aD4BerJM6iy4IX1TJxv.jpg'},
#  {'id': 24428,
#   'title': 'The Avengers',
#   'overview': 'When an unexpected enemy emerges and threatens global safety and security, Nick Fury, director of the international peacekeeping agency known as S.H.I.E.L.D., finds himself in need of a team to pull the world back from the brink of disaster. Spanning the globe, a daring recruitment effort begins!',
#   'genres': "['Science Fiction', 'Action', 'Adventure']",
#   'cast': "['Robert Downey Jr.', 'Chris Evans', 'Mark Ruffalo', 'Chris Hemsworth', 'Scarlett Johansson', 'Jeremy Renner', 'Tom Hiddleston', 'Clark Gregg', 'Cobie Smulders', 'Stellan Skarsgård']",
#   'director': 'Joss Whedon',
#   'keywords': "['new york city', 'superhero', 'shield', 'based on comic', 'alien invasion', 'superhero team', 'aftercreditsstinger', 'duringcreditsstinger', 'marvel cinematic universe (mcu)']",
#   'rating': 7.884,
#   'vote_count': 34618,
#   'release_date': '2012-04-25',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/RYMX2wcKCBAr24UyPD7xwmjaTn.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/9BBTo63ANSmhC4e6r62OJFuK2GL.jpg'},
#  {'id': 1363123,
#   'title': 'The Family Plan 2',
#   'overview': "Now that Dan's assassin days are behind him, all he wants for Christmas is quality time with his kids. But when he learns his daughter has her own plans, he books a family trip to London—putting them all in the crosshairs of an unexpected enemy.",
#   'genres': "['Action', 'Comedy']",
#   'cast': "['Mark Wahlberg', 'Michelle Monaghan', 'Kit Harington', 'Zoe Colletti', 'Van Crosby', 'Theodore Lindsey', 'Peter Lindsey', 'Reda Elazouar', 'Sidse Babett Knudsen', 'Sanjeev Bhaskar']",
#   'director': 'Simon Cellan Jones',
#   'keywords': "['europe vacation']",
#   'rating': 6.64,
#   'vote_count': 393,
#   'release_date': '2025-11-11',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/semFxuYx6HcrkZzslgAkBqfJvZk.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/7nAVXGHHtaNcdsqvDXmY6R9N0fG.jpg'},
#  {'id': 23527,
#   'title': 'First Squad: The Moment of Truth',
#   'overview': 'Set during the opening days of World War II on the Eastern Front. Its main cast are a group of Soviet teenagers with extraordinary abilities; the teenagers have been drafted to form a special unit to fight the invading German army. They are opposed by a Schutzstaffel officer who is attempting to raise from the dead a supernatural army of crusaders from the 12th-century Order of the Sacred Cross.',
#   'genres': "['Fantasy', 'Animation', 'Action', 'Science Fiction']",
#   'cast': "['Sergei Aisman', 'Michael Beskorovainy', 'Elena Chebaturkina', 'Damir Eldarov', 'Olga Golovanova', 'Alexander Gruzdev', 'Artem Kipnis', 'Rudolf Pankov', 'Mikhail Tikhonov', 'Nikita Prozorovsky']",
#   'director': 'Alexey Klimov',
#   'keywords': "['supernatural', 'super soldier', 'russian army']",
#   'rating': 6.248,
#   'vote_count': 139,
#   'release_date': '2009-05-13',
#   'imdb_rating': 5.6,
#   'imdb_votes': '1,873',
#   'poster_url': 'https://image.tmdb.org/t/p/w500/hBj1aTnGf4564Klv9yIbSuB7Y8w.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/3k1PKmzNEosWFaOR1yC9ZKIYqmm.jpg'},
#  {'id': 1116465,
#   'title': 'A Legend',
#   'overview': 'An archeologist noticed that the texture of the relics discovered during the excavation of a glacier closely resembled a jade pendant seen in one of his dreams. He and his team then embark on an expedition into the depths of the glacier.',
#   'genres': "['Action', 'Adventure', 'Fantasy']",
#   'cast': "['Jackie Chan', 'Zhang Yixing', 'Gulnezer Bextiyar', 'Aarif Rahman', 'Jerry Lee', 'Peng Xiaoran', 'Shawn Dou', 'Zheng Yecheng', 'Ma Yuan', 'Ray Lui']",
#   'director': 'Stanley Tong Gwai-Lai',
#   'keywords': "['burlesque', 'inspirational', 'admiring', 'amused', 'awestruck', 'hopeful']",
#   'rating': 6.862,
#   'vote_count': 130,
#   'release_date': '2024-07-05',
#   'imdb_rating': 4.7,
#   'imdb_votes': '1,189',
#   'poster_url': 'https://image.tmdb.org/t/p/w500/qbImUt1d3itXcB81BCItPZlfbyr.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/7FDVhmCur4LMOfnXMteiSCtsdOb.jpg'},
#  {'id': 1234821,
#   'title': 'Jurassic World Rebirth',
#   'overview': "Five years after the events of Jurassic World Dominion, covert operations expert Zora Bennett is contracted to lead a skilled team on a top-secret mission to secure genetic material from the world's three most massive dinosaurs. When Zora's operation intersects with a civilian family whose boating expedition was capsized, they all find themselves stranded on an island where they come face-to-face with a sinister, shocking discovery that's been hidden from the world for decades.",
#   'genres': "['Science Fiction', 'Adventure', 'Action']",
#   'cast': "['Scarlett Johansson', 'Mahershala Ali', 'Jonathan Bailey', 'Rupert Friend', 'Manuel Garcia-Rulfo', 'Luna Blaise', 'David Iacono', 'Audrina Miranda', 'Philippine Velge', 'Bechir Sylvain']",
#   'director': 'Gareth Edwards',
#   'keywords': "['island', 'secret mission', 'stranded', 'dinosaur', 'family', 'genetic experiment', 'absurd']",
#   'rating': 6.37,
#   'vote_count': 2648,
#   'release_date': '2025-07-01',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/1RICxzeoNCAO5NpcRMIgg1XT6fm.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/fQOV47FHTJdaSuSUNlzP3zXUZWE.jpg'},
#  {'id': 911430,
#   'title': 'F1',
#   'overview': 'Racing legend Sonny Hayes is coaxed out of retirement to lead a struggling Formula 1 team—and mentor a young hotshot driver—while chasing one more chance at glory.',
#   'genres': "['Action', 'Drama']",
#   'cast': "['Brad Pitt', 'Damson Idris', 'Javier Bardem', 'Kerry Condon', 'Tobias Menzies', 'Kim Bodnia', 'Sarah Niles', 'Will Merrick', 'Joseph Balderrama', 'Abdul Salis']",
#   'director': 'Joseph Kosinski',
#   'keywords': "['comeback', 'racing', 'race car driver', 'sport competition', 'beforecreditsstinger', 'rookie', 'formula one (f1)', 'motorsport', 'car racing', 'admiring', 'sport']",
#   'rating': 7.798,
#   'vote_count': 2864,
#   'release_date': '2025-06-25',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/9PXZIUsSDh4alB80jheWX4fhZmy.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/lkDYN0whyE82mcM20rwtwjbniKF.jpg'},
#  {'id': 1309012,
#   'title': 'Altered',
#   'overview': 'In an alternate present, genetically enhanced humans dominate society. Outcasts Leon and Chloe fight for justice against corrupt politicians exploiting genetic disparity, risking everything to challenge the oppressive system.',
#   'genres': "['Science Fiction', 'Action']",
#   'cast': "['Tom Felton', 'Aggy K. Adams', 'Elizaveta Bugulova', 'Igor Jijikine', 'Richard Brake', 'Aleksey Filimonov', 'Daniyar Alshinov', 'Atamura Mussakhanov', 'Linda Nigmatulina', 'Yelzhas Rakhim']",
#   'director': 'Timo Vuorensola',
#   'keywords': '[]',
#   'rating': 6.224,
#   'vote_count': 67,
#   'release_date': '2025-09-18',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/6QlAcGRaUrgHcZ4WTBh5lsPnzKx.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/q9bvjUkpKltPE0S9oxci2pmD1Zx.jpg'},
#  {'id': 845781,
#   'title': 'Red One',
#   'overview': "After Santa Claus (codename: Red One) is kidnapped, the North Pole's Head of Security must team up with the world's most infamous tracker in a globe-trotting, action-packed mission to save Christmas.",
#   'genres': "['Action', 'Comedy', 'Fantasy']",
#   'cast': "['Dwayne Johnson', 'Chris Evans', 'Lucy Liu', 'J.K. Simmons', 'Kiernan Shipka', 'Bonnie Hunt', 'Kristofer Hivju', 'Mary Elizabeth Ellis', 'Wesley Kimmel', 'Nick Kroll']",
#   'director': 'Jake Kasdan',
#   'keywords': "['rescue', 'bounty hunter', 'holiday', 'kidnapping', 'santa claus', 'rescue mission', 'polar bear', 'rescue team', 'christmas', 'action comedy', 'christmas eve', 'family comedy', 'defence team']",
#   'rating': 7.0,
#   'vote_count': 2830,
#   'release_date': '2024-10-31',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/cdqLnri3NEGcmfnqwk2TSIYtddg.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/rOmUuQEZfPXglwFs5ELLLUDKodL.jpg'},
#  {'id': 1469354,
#   'title': 'Border Hunters',
#   'overview': 'After his police officer brother is killed by a drug dealer who flees to the protection of his cartel-connected uncle in Mexico, an American man with a diverse law enforcement/military background goes south of the border to get revenge',
#   'genres': "['Action', 'Thriller']",
#   'cast': "['Dean Norris', 'Julio Macias', 'Danforth Comins', 'Ramón Medína', 'Pía Sanz', 'Eligio Meléndez', 'Christina Urias', 'Luis Velázquez']",
#   'director': 'Ruben Islas',
#   'keywords': "['absurd']",
#   'rating': 7.0,
#   'vote_count': 15,
#   'release_date': '2025-10-20',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/6TNFZnJ5CU0uFQxGaO9dbqriiI7.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/tRdorrIjlybrGsebXOzgF7vRyYy.jpg'},
#  {'id': 27205,
#   'title': 'Inception',
#   'overview': 'Cobb, a skilled thief who commits corporate espionage by infiltrating the subconscious of his targets is offered a chance to regain his old life as payment for a task considered to be impossible: "inception", the implantation of another person\'s idea into a target\'s subconscious.',
#   'genres': "['Action', 'Science Fiction', 'Adventure']",
#   'cast': "['Leonardo DiCaprio', 'Joseph Gordon-Levitt', 'Ken Watanabe', 'Tom Hardy', 'Elliot Page', 'Dileep Rao', 'Cillian Murphy', 'Tom Berenger', 'Marion Cotillard', 'Pete Postlethwaite']",
#   'director': 'Christopher Nolan',
#   'keywords': "['rescue', 'mission', 'dreams', 'airplane', 'paris, france', 'virtual reality', 'kidnapping', 'philosophy', 'spy', 'allegory', 'manipulation', 'car crash', 'heist', 'memory', 'architecture', 'los angeles, california', 'death', 'dream world', 'insecure', 'subconscious', 'intense', 'dream']",
#   'rating': 8.371,
#   'vote_count': 38384,
#   'release_date': '2010-07-15',
#   'imdb_rating': 8.8,
#   'imdb_votes': '2,757,709',
#   'poster_url': 'https://image.tmdb.org/t/p/w500/xlaY2zyzMfkhk0HSC5VUwzoZPU1.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/ii8QGacT3MXESqBckQlyrATY0lT.jpg'},
#  {'id': 562,
#   'title': 'Die Hard',
#   'overview': "NYPD cop John McClane's plan to reconcile with his estranged wife is thrown for a serious loop when, minutes after he arrives at her offices Christmas Party, the entire building is overtaken by a group of terrorists. With little help from the LAPD, wisecracking McClane sets out to single-handedly rescue the hostages and bring the bad guys down.",
#   'genres': "['Action', 'Thriller']",
#   'cast': '[\'Bruce Willis\', \'Alan Rickman\', \'Alexander Godunov\', \'Bonnie Bedelia\', \'Reginald VelJohnson\', \'Paul Gleason\', "De\'voreaux White", \'William Atherton\', \'Hart Bochner\', \'James Shigeta\']',
#   'director': 'John McTiernan',
#   'keywords': "['husband wife relationship', 'based on novel or book', 's.w.a.t.', 'fbi', 'christmas party', 'vault', 'heist', 'murder', 'shootout', 'los angeles, california', 'terrorism', 'one man army', 'explosion', 'police officer', 'hostage negotiator', 'one night', 'lapd', 'christmas', '1980s', 'action hero', 'german', 'hostages', 'patrol officer', 'high octane']",
#   'rating': 7.804,
#   'vote_count': 11869,
#   'release_date': '1988-07-15',
#   'imdb_rating': 8.2,
#   'imdb_votes': '1,003,024',
#   'poster_url': 'https://image.tmdb.org/t/p/w500/7Bjd8kfmDSOzpmhySpEhkUyK2oH.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/oIwfoUFfWfESn0Y8u8jv9lc8li1.jpg'},
#  {'id': 949709,
#   'title': 'High Forces',
#   'overview': '"Anyone? There is ......" A mysterious message from Gao Haojun comes from ten thousand meters in the air. A five-star A380 ultra-luxury airliner was hijacked on its international maiden voyage, and international security expert Gao Haojun stood up to a group of thugs, his daughter Xiaojun was trapped in the cabin, and Mike, the leader of the hijackers, threatened the lives of more than 800 people in the plane as a bargaining chip, and Xiaojun\'s mother, Fu Yuan, was also in danger. ...... Will the passengers on board be able to land safely and how should this crisis be resolved?',
#   'genres': "['Action', 'Crime']",
#   'cast': "['Andy Lau', 'Zhang Zifeng', 'Qu Chuxiao', 'Liu Tao', 'Guo Xiaodong', 'Jiang Mengjie', 'David Wang', 'Jiang Chao', 'Wang Longzheng', 'Zhang Yang']",
#   'director': 'Oxide Pang Chun',
#   'keywords': "['airplane', 'hijacking', 'airplane hijacking', 'disaster']",
#   'rating': 5.931,
#   'vote_count': 29,
#   'release_date': '2024-09-29',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/v8ySgr4CE45SrrIt4PqqYc1diW6.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/8lqfrOBQ2EcY7znD3LxTYcvlh25.jpg'},
#  {'id': 1233413,
#   'title': 'Sinners',
#   'overview': 'Trying to leave their troubled lives behind, twin brothers return to their hometown to start again, only to discover that an even greater evil is waiting to welcome them back.',
#   'genres': "['Horror', 'Action', 'Thriller']",
#   'cast': '[\'Michael B. Jordan\', \'Hailee Steinfeld\', \'Miles Caton\', "Jack O\'Connell", \'Wunmi Mosaku\', \'Jayme Lawson\', \'Omar Benson Miller\', \'Delroy Lindo\', \'Li Jun Li\', \'Yao\']',
#   'director': 'Ryan Coogler',
#   'keywords': "['chicago, illinois', 'capitalism', 'ku klux klan', 'musician', 'immortality', 'vampire', 'surrealism', 'sin', 'alcoholism', 'vampire hunter (slayer)', 'church', 'twins', 'blunt', 'estranged wife', 'dual role', 'cousin relationship', 'death of daughter', 'blues music', 'aftercreditsstinger', 'klansmen', '1990s', '1930s', 'salvation', 'assimilation', 'chinese immigrant', 'brother brother relationship', 'southern gothic', 'afro-descendants', 'cousins', 'supernatural horror', 'playful', 'train station', 'mississippi', 'frightened']",
#   'rating': 7.503,
#   'vote_count': 3065,
#   'release_date': '2025-04-16',
#   'imdb_rating': 7.6,
#   'imdb_votes': '312,879',
#   'poster_url': 'https://image.tmdb.org/t/p/w500/qTvFWCGeGXgBRaINLY1zqgTPSpn.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/nAxGnGHOsfzufThz20zgmRwKur3.jpg'},
#  {'id': 840326,
#   'title': 'Sisu',
#   'overview': 'When an ex-soldier who discovers gold in the Lapland wilderness tries to take the loot into the city, German soldiers led by a brutal SS officer battle him.',
#   'genres': "['Action', 'War']",
#   'cast': "['Jorma Tommila', 'Aksel Hennie', 'Jack Doolan', 'Mimosa Willamo', 'Onni Tommila', 'Tatu Sinisalo', 'Wilhelm Enckell', 'Vincent Willestrand', 'Arttu Kapulainen', 'Elina Saarela']",
#   'director': 'Jalmari Helander',
#   'keywords': "['world war ii', 'lapland', 'nordic mythology', 'soldier', 'aggressive', 'finnish mythology', 'bloody', 'absurd', 'violence', 'hilarious', 'lapland war']",
#   'rating': 7.412,
#   'vote_count': 2583,
#   'release_date': '2022-09-09',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
# ...
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/pEzNVQfdzYDzVK0XqxERIw2x2se.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/hNCqkXbWd40eftqSdjq8TmV7Mqr.jpg'},
#  {'id': 46738,
#   'title': 'Incendies',
#   'overview': "A mother's last wishes send twins Jeanne and Simon on a journey to Middle East in search of their tangled roots. Adapted from Wajdi Mouawad's acclaimed play, Incendies tells the powerful and moving tale of two young adults' voyage to the core of deep-rooted hatred, never-ending wars and enduring love.",
#   'genres': "['Drama', 'War', 'Mystery']",
#   'cast': "['Lubna Azabal', 'Mélissa Désormeaux-Poulin', 'Maxim Gaudette', 'Rémy Girard', 'Allen Altman', 'Abdelghafour Elaaziz', 'Dominique Briand', 'Frédéric Paquet', 'Ahmad Massad', 'John Dunn-Hill']",
#   'director': 'Denis Villeneuve',
#   'keywords': "['prison', 'rape', 'middle east', 'muslim', 'militia', 'orphanage', 'son', 'interpreter', 'swimming pool', 'massacre', 'checkpoint', 'political assassination', 'twins', 'incest', 'will', 'domineering', 'lebanese civil war', 'lebanon', 'intense', 'mother son incest', 'incest rape']",
#   'rating': 8.107,
#   'vote_count': 3100,
#   'release_date': '2010-09-17',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/yH6DAQVgbyj72S66gN4WWVoTjuf.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/f3ATwil5vmUeTsogBaMEKbBYBth.jpg'},
#  {'id': 1124,
#   'title': 'The Prestige',
#   'overview': 'A mysterious story of two magicians whose intense rivalry leads them on a life-long battle for supremacy -- full of obsession, deceit and jealousy with dangerous and deadly consequences.',
#   'genres': "['Drama', 'Mystery', 'Science Fiction']",
#   'cast': "['Hugh Jackman', 'Christian Bale', 'Michael Caine', 'Piper Perabo', 'Rebecca Hall', 'Scarlett Johansson', 'Samantha Mahurin', 'David Bowie', 'Andy Serkis', 'Daniel Davis']",
#   'director': 'Christopher Nolan',
#   'keywords': "['dying and death', 'suicide', 'class society', 'london, england', 'magic', 'competition', 'obsession', 'hostility', 'class', 'diary', 'twist', 'tricks', 'illusion', 'rivalry', 'partner', 'steampunk', 'cruelty', 'hanging', 'jail cell', '19th century', 'nikola tesla', 'magician', 'tesla coil', 'bittersweet', 'secret', 'direct', 'mind-blowing', 'antagonistic', 'embarrassed', 'pretentious']",
#   'rating': 8.206,
#   'vote_count': 17041,
#   'release_date': '2006-10-17',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/bdN3gXuIZYaJP7ftKK2sU0nPtEA.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/yCnJT53HMXAK87xzPAdjdYhZ3JE.jpg'},
#  {'id': 1233575,
#   'title': 'Black Bag',
#   'overview': 'When intelligence agent Kathryn Woodhouse is suspected of betraying the nation, her husband – also a legendary agent – faces the ultimate test of whether to be loyal to his marriage, or his country.',
#   'genres': "['Drama', 'Mystery', 'Thriller']",
#   'cast': "['Cate Blanchett', 'Michael Fassbender', 'Tom Burke', 'Marisa Abela', 'Regé-Jean Page', 'Naomie Harris', 'Pierce Brosnan', 'Kae Alexander', 'Ambika Mod', 'Gustaf Skarsgård']",
#   'director': 'Steven Soderbergh',
#   'keywords': "['london, england', 'husband wife relationship', 'spy', 'marriage', 'suspicion', 'dinner', 'intelligence officer', 'calm', 'polygraph', 'modest', 'zurich, switzerland']",
#   'rating': 6.3,
#   'vote_count': 1010,
#   'release_date': '2025-03-12',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/hHPovtU4b96LHcoeEwRkGHI5btw.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/gxO51FVgADhYGGnnRPIlutVqb30.jpg'},
#  {'id': 70981,
#   'title': 'Prometheus',
#   'overview': 'A team of explorers discover a clue to the origins of mankind on Earth, leading them on a journey to the darkest corners of the universe. There, they must fight a terrifying battle to save the future of the human race.',
#   'genres': "['Science Fiction', 'Adventure', 'Mystery']",
#   'cast': "['Noomi Rapace', 'Michael Fassbender', 'Charlize Theron', 'Idris Elba', 'Guy Pearce', 'Logan Marshall-Green', 'Sean Harris', 'Rafe Spall', 'Emun Elliott', 'Benedict Wong']",
#   'director': 'Ridley Scott',
#   'keywords': "['android', 'alien', 'space', 'creature', 'spin off', 'creation', 'emergency surgery', 'archaeological dig', 'stasis', 'god complex', 'cave drawing', 'prometheus', 'genetic mutation', 'origins of life', 'lovecraftian', '2090s', 'objective']",
#   'rating': 6.589,
#   'vote_count': 12897,
#   'release_date': '2012-05-30',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/qsYQflQhOuhDpQ0W2aOcwqgDAeI.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/qDG5SlGkWNsjSJWiGTBMFI8DpzA.jpg'},
#  {'id': 10403,
#   'title': 'The Player',
#   'overview': 'A Hollywood studio executive is being sent death threats by a writer whose script he rejected - but which one?',
#   'genres': "['Mystery', 'Drama', 'Thriller', 'Comedy']",
#   'cast': '[\'Tim Robbins\', \'Greta Scacchi\', \'Fred Ward\', \'Whoopi Goldberg\', \'Peter Gallagher\', \'Brion James\', \'Cynthia Stevenson\', "Vincent D\'Onofrio", \'Dean Stockwell\', \'Richard E. Grant\']',
#   'director': 'Robert Altman',
#   'keywords': "['based on novel or book', 'homicide', 'movie business', 'blackmail', 'screenwriter', 'hollywood', 'death threat', 'movie mogul', 'movie studio', 'studio executive']",
#   'rating': 7.196,
#   'vote_count': 904,
#   'release_date': '1992-05-08',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/tZ3kDut2dhFVGkWNEn9xoCHCNAx.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/rXj1UrzBqsbiCbH1ntJ5yDeysYc.jpg'},
#  {'id': 251,
#   'title': 'Ghost',
#   'overview': 'After a young man is murdered, his spirit stays behind to warn his lover of impending danger, with the help of a reluctant psychic.',
#   'genres': "['Fantasy', 'Drama', 'Thriller', 'Mystery', 'Romance']",
#   'cast': "['Patrick Swayze', 'Demi Moore', 'Whoopi Goldberg', 'Tony Goldwyn', 'Vincent Schiavelli', 'Rick Aviles', 'Martina Deignan', 'Rick Kleber', 'Phil Leeds', 'Armelia McQueen']",
#   'director': 'Jerry Zucker',
#   'keywords': "['fortune teller', 'corruption', 'soulmates', 'afterlife', 'money transfer', 'money laundering', 'pottery', 'hell', 'heaven', 'love', 'murder', 'death', 'ghost', 'power of love', 'spiritism', 'everlasting love']",
#   'rating': 7.227,
#   'vote_count': 5841,
#   'release_date': '1990-07-13',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/w9RaPHov8oM5cnzeE27isnFMsvS.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/6nLdSON3ErniBZTXWG7WRqs5jGz.jpg'},
#  {'id': 15472,
#   'title': 'The Girl with the Dragon Tattoo',
#   'overview': "Swedish thriller based on Stieg Larsson's novel about a male journalist and a young female hacker. In the opening of the movie, Mikael Blomkvist, a middle-aged publisher for the magazine Millennium, loses a libel case brought by corrupt Swedish industrialist Hans-Erik Wennerström. Nevertheless, he is hired by Henrik Vanger in order to solve a cold case, the disappearance of Vanger's niece",
#   'genres': "['Drama', 'Thriller', 'Crime', 'Mystery']",
#   'cast': "['Michael Nyqvist', 'Noomi Rapace', 'Lena Endre', 'Sven-Bertil Taube', 'Peter Haber', 'Peter Andersson', 'Marika Lagercrantz', 'Ingvar Hirdwall', 'Björn Granath', 'Ewa Fröling']",
#   'director': 'Niels Arden Oplev',
#   'keywords': "['journalist', 'island', 'bondage', 'rape', 'strong woman', 'hacker', 'based on novel or book', 'nazi', 'blow job', 'antisocial personality disorder', 'female protagonist', 'whodunit', 'newspaper man', 'millennium', 'female empowerment', 'locked room mystery', 'girl with piercings', 'woman murder']",
#   'rating': 7.532,
#   'vote_count': 3119,
#   'release_date': '2009-02-27',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/6w0TKhfR0Rzby5SXxgfuI99Jrva.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/dPE25PbaeE6fCR2SQb4H4MeBmml.jpg'},
#  {'id': 745,
#   'title': 'The Sixth Sense',
#   'overview': 'Following an unexpected tragedy, child psychologist Malcolm Crowe meets a nine year old boy named Cole Sear, who is hiding a dark secret.',
#   'genres': "['Mystery', 'Thriller', 'Drama']",
#   'cast': "['Bruce Willis', 'Haley Joel Osment', 'Toni Collette', 'Olivia Williams', 'Donnie Wahlberg', 'Trevor Morgan', 'Mischa Barton', 'Angelica Page', 'Greg Wood', 'Peter Anthony Tambakis']",
#   'director': 'M. Night Shyamalan',
#   'keywords': "['dying and death', 'child abuse', 'philadelphia, pennsylvania', 'sense of guilt', 'afterlife', 'marriage crisis', 'loss of loved one', 'confidence', 'psychology', 'paranormal phenomena', 'single', 'psychological thriller', 'cowardliness', 'single mother', 'school play', 'ghost', 'kids', 'spiritism', 'anxious', 'ghost child', 'dramatic', 'appreciative', 'supernatural thriller']",
#   'rating': 7.947,
#   'vote_count': 12435,
#   'release_date': '1999-08-06',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/vOyfUXNFSnaTk7Vk5AjpsKTUWsu.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/paUKxrbN2ww0JeT2JtvgAuaGlPf.jpg'},
#  {'id': 24886,
#   'title': 'Minor Details',
#   'overview': "Someone at the prestigious Danforth Academy is trying to make the students sick. Is it Mia or Riley, the rich girls? Or could it be Emily, the Principal's daughter? Whoever it is, Abby, Paige, Claire and Taylor will have to put aside their differences and join together to solve the mystery!",
#   'genres': "['Adventure', 'Family', 'Mystery']",
#   'cast': "['Kelsey Edwards', 'Caitlin E.J. Meyer', 'Danielle C. Ryan', 'Lauren Faber', 'Jennette McCurdy', 'Savannah Jayde', 'Emma Duke', 'Brady Edwards', 'Andrew Cottrill', 'Elijah Thomas']",
#   'director': 'John Lyde',
#   'keywords': "['boarding school', 'aftercreditsstinger', 'high school rivalry', 'poisoning']",
#   'rating': 7.2,
#   'vote_count': 46,
#   'release_date': '2009-02-05',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/c9xkBqj0YjmG4FtV7psJBz8ehcl.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/a8WVUYxdkduCqZImdN3RqriIDhV.jpg'},
#  {'id': 17532,
#   'title': 'S. Darko',
#   'overview': "Seven years after the events of the first film, Samantha Darko finds herself stranded in a small desert town after her car breaks down where she is plagued by bizarre visions telling of the universe's end. As a result, she must face her own demons, and in doing so, save the world and herself.",
#   'genres': "['Thriller', 'Crime', 'Science Fiction', 'Mystery']",
#   'cast': "['Daveigh Chase', 'Elizabeth Berkley', 'Briana Evigan', 'James Lafferty', 'Ed Westwick', 'Bret Roberts', 'Jackson Rathbone', 'Barbara Tarbuck', 'Matthew Davis', 'Walter Platz']",
#   'director': 'Chris Fisher',
#   'keywords': "['sequel', 'end of the world', 'stranded', 'shattered home', 'bizarre past']",
#   'rating': 4.4,
#   'vote_count': 480,
#   'release_date': '2009-04-28',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/djuhoG2GizTa9SLi2LBuCPAt6N7.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/2oxlor4lQrP2JX40ammAQdOqkEQ.jpg'},
#  {'id': 296065,
#   'title': 'Last Shift',
#   'overview': "Rookie police officer Jessica Loren has been assigned the last shift at a closing police station and must wait for a hazmat crew to collect biomedical evidence. Ordered not to leave the station under any circumstances, Jessica comes to learn that it's more than just an outdated station, it's home to the ultimate embodiment of evil and his devoted bloodthirsty followers. Jessica is left to fend for herself in the Devil's playground.",
#   'genres': "['Horror', 'Mystery']",
#   'cast': "['Juliana Harkavy', 'Joshua Mikel', 'Hank Stone', 'J. LaRose', 'Sarah Sculco', 'Kathryn Kilger', 'Natalie Victoria', 'Mary Lankford Poiley', 'Matt Doman', 'Lindsi Jeter']",
#   'director': 'Anthony DiBlasi',
#   'keywords': "['mask', 'supernatural', 'hell', 'telephone', 'cop', 'female protagonist', 'police station', 'hanging', 'rookie cop', 'jail cell', 'cult leader']",
#   'rating': 6.275,
#   'vote_count': 677,
#   'release_date': '2014-10-25',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/oSTFMqFpVB4yq9SOIxBp8xZ9jh5.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/gYhheyDkKanBAN2JAi7ZuPiwH36.jpg'},
#  {'id': 308,
#   'title': 'Broken Flowers',
#   'overview': 'Introverted Don Johnston receives an anonymous letter from an ex-lover informing him that he has a son who may be looking for him. A freelance sleuth neighbor motivates Don to embark on a cross-country search for his past flames seeking answers.',
#   'genres': "['Comedy', 'Drama', 'Mystery', 'Romance']",
#   'cast': "['Bill Murray', 'Sharon Stone', 'Jessica Lange', 'Tilda Swinton', 'Frances Conroy', 'Alexis Dziena', 'Chloë Sevigny', 'Christopher McDonald', 'Julie Delpy', 'Jeffrey Wright']",
#   'director': 'Jim Jarmusch',
#   'keywords': "['unsociability', 'midlife crisis', 'bachelor', 'amateur detective', 'ex-boyfriend', 'ex-girlfriend', 'veterinarian', 'anonymous letter', 'it-expert']",
#   'rating': 6.921,
#   'vote_count': 1431,
#   'release_date': '2005-07-31',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/gd8JNjwgiM6ZgGm6NFAkovQWoYn.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/xTO4x2OyF7TdZ32mVnjzhjslDOd.jpg'},
#  {'id': 23437,
#   'title': 'A Nightmare on Elm Street',
#   'overview': 'Teenagers Nancy, Quentin, Kris, Jesse and Dean are all neighborhood friends who begin having the same dream of a horribly disfigured man who wears a tattered sweater and a glove made of knives. The man terrorizes them in their dreams, and the only escape is to wake up. But when, one by one, they start dying violently, the friends realize that what happens in the dream world is real, and the only way to stay alive is to stay awake.',
#   'genres': "['Horror', 'Mystery', 'Thriller']",
#   'cast': "['Rooney Mara', 'Kyle Gallner', 'Jackie Earle Haley', 'Katie Cassidy', 'Thomas Dekker', 'Kellan Lutz', 'Clancy Brown', 'Connie Britton', 'Lia D. Mortensen', 'Julianna Damm']",
#   'director': 'Samuel Bayer',
#   'keywords': "['child abuse', 'dreams', 'supernatural', 'elementary school', 'remake', 'revenge', 'slasher', 'child molester', 'burn victim', 'reboot', 'reality vs fantasy', 'dark fantasy', 'repressed memory', 'nightmare becomes reality', 'sleep deprivation', 'pre-school', 'loss of innocence', 'coping mechanisms', 'sexual predator', 'complex', 'supernatural horror', 'repressed trauma', 'vigilante justice', 'underrated', 'parents and child', 'nightmares', 'cruel', 'mean spirited', 'accusation of child molestation']",
#   'rating': 5.531,
#   'vote_count': 2841,
#   'release_date': '2010-04-30',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/nsmW28GcNabCUZfP5YtUEe8Li0f.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/8sZ2FZJMw971rpPZvkraVAFBM92.jpg'},
#  {'id': 8859,
#   'title': "Dude, Where's My Car?",
#   'overview': 'Two stoners wake up after a night of partying and cannot remember where they parked their car.',
#   'genres': "['Comedy', 'Romance', 'Science Fiction', 'Mystery']",
#   'cast': '[\'Ashton Kutcher\', \'Seann William Scott\', \'Jennifer Garner\', \'Marla Sokoloff\', \'Kristy Swanson\', \'David Herman\', \'Hal Sparks\', "Charlie O\'Connell", \'John Toles-Bey\', \'Christian Middelthon\']',
#   'director': 'Danny Leiner',
#   'keywords': "['friendship', 'amnesia', 'tattoo', 'idiot', 'girlfriend', 'stupidity', 'cannabis', 'hangover', 'spoof', 'drugs', 'alcohol abuse', 'celebration', 'duringcreditsstinger', 'kids', 'stoner movie']",
#   'rating': 5.535,
#   'vote_count': 2000,
#   'release_date': '2000-12-15',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/A5FBQplPsSVVvdYn4NHgtWYF8un.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/xrziJc1RpB5ZI0FYvm4ALxZ6Hi2.jpg'},
#  ...]

# %%
df.shape
# Out:
# (1520, 14)

# %%
DB_NAME = "movie_recommender"
COLLECTION_NAME = "movies_metadata"

CONNECTION_URL='mongodb+srv://yeshwanthdandu2003_db_user:xIewgpD4PBgP5hWq@cluster0.9hxbbgf.mongodb.net/?appName=Cluster0'

# %%
client=pymongo.MongoClient(CONNECTION_URL)
data_base=client[DB_NAME]
collection=data_base[COLLECTION_NAME]

# %%
# Uploading data to MongoDB
rec=collection.insert_many(data)

# %%
df.shape
# Out:
# (1520, 14)

# %%
df.isnull().sum()
# Out:
# id                 0
# title              0
# overview           0
# genres             0
# cast               0
# director           0
# keywords           0
# rating             0
# vote_count         0
# release_date       0
# imdb_rating     1484
# imdb_votes      1483
# poster_url         0
# backdrop_url      13
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1520 entries, 0 to 1519
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1520 non-null   int64
#  1   title         1520 non-null   object
#  2   overview      1520 non-null   object
#  3   genres        1520 non-null   object
#  4   cast          1520 non-null   object
#  5   director      1520 non-null   object
#  6   keywords      1520 non-null   object
#  7   rating        1520 non-null   float64
#  8   vote_count    1520 non-null   int64
#  9   release_date  1520 non-null   object
#  10  imdb_rating   36 non-null     float64
#  11  imdb_votes    37 non-null     object
#  12  poster_url    1520 non-null   object
#  13  backdrop_url  1507 non-null   object
# dtypes: float64(2), int64(2), object(10)
# memory usage: 166.4+ KB

# %%
#dropping the columns fo imbd_rating and imbd_votes
df = df.drop(columns=["imdb_rating", "imdb_votes"], errors="ignore")

# %%
df.isnull().sum()
# Out:
# id               0
# title            0
# overview         0
# genres           0
# cast             0
# director         0
# keywords         0
# rating           0
# vote_count       0
# release_date     0
# poster_url       0
# backdrop_url    13
# dtype: int64

# %%
df.describe()
# Out:
#                  id       rating    vote_count
# count  1.520000e+03  1520.000000   1520.000000
# mean   4.145888e+05     6.806216   3900.056579
# std    4.648157e+05     0.920068   6284.984210
# min    1.100000e+01     3.115000     11.000000
# 25%    1.346150e+04     6.244500     77.750000
# 50%    2.070540e+05     6.900000    714.500000
# 75%    7.640380e+05     7.459500   4787.750000
# max    1.589891e+06     9.300000  38455.000000
